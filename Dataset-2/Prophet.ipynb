# %% [markdown]
# <a href="https://colab.research.google.com/github/gr3g-z/TCC-PUCSP-CDIA/blob/main/Dataset-2/Prophet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extração dos Dados e Feature Engineering

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
import numpy as np

# %%
transactions = pd.read_csv('/content/drive/MyDrive/store_sales/transactions.csv')
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB

# %%
# Carregar o DataFrame do arquivo pickle
df_clusterizado = pd.read_pickle('/content/drive/MyDrive/store_sales/df_clusterizado.pkl')
df_clusterizado = df_clusterizado.rename(columns={'loja': 'store_nbr'})
df_clusterizado
# Out:
#     store_nbr  Soma vendas totais  Contagem vendas totais  Media por venda  \
# 0           1        1.414501e+07                 2553963         5.538456
# 1           2        2.155739e+07                 3219901         6.695047
# 2           3        5.048191e+07                 5366350         9.407122
# 3           4        1.890970e+07                 2519007         7.506807
# 4           5        1.559240e+07                 2347877         6.641065
# 5           6        2.518368e+07                 3065896         8.214134
# 6           7        2.695205e+07                 2995993         8.996032
# 7           8        3.049429e+07                 4637971         6.574920
# 8           9        2.640944e+07                 3516162         7.510872
# 9          10        9.613906e+06                 1652493         5.817819
# 10         11        2.832556e+07                 3972488         7.130433
# 11         12        1.065922e+07                 1958852         5.441564
# 12         13        1.052305e+07                 1572504         6.691904
# 13         14        1.138792e+07                 2287850         4.977564
# 14         15        1.145127e+07                 2209898         5.181809
# 15         16        1.098641e+07                 1464498         7.501828
# 16         17        1.803097e+07                 2295485         7.854971
# 17         18        1.325938e+07                 2071278         6.401543
# 18         19        1.304951e+07                 2107489         6.191971
# 19         20        1.292095e+07                 1422539         9.083023
# 20         21        9.255506e+06                  842891        10.980668
# 21         22        4.090202e+06                  504156         8.112968
# 22         23        1.165138e+07                 1788171         6.515809
# 23         24        2.376773e+07                 3568206         6.660975
# 24         25        1.142100e+07                 1520362         7.512025
# 25         26        7.755122e+06                 1065059         7.281401
# 26         27        1.918802e+07                 2485687         7.719404
# 27         28        1.838315e+07                 1957594         9.390688
# 28         29        9.725158e+06                  981448         9.908989
# 29         30        7.382074e+06                 1171130         6.303377
# 30         31        1.774687e+07                 2306044         7.695808
# 31         32        5.951796e+06                 1065226         5.587355
# 32         33        1.417850e+07                 1743003         8.134525
# 33         34        1.709073e+07                 3864018         4.423047
# 34         35        7.676679e+06                 1123889         6.830461
# 35         36        1.532243e+07                 1738129         8.815474
# 36         37        1.997064e+07                 2481719         8.047098
# 37         38        1.886000e+07                 2867052         6.578185
# 38         39        2.025219e+07                 2389482         8.475558
# 39         40        1.839576e+07                 2181195         8.433798
# 40         41        1.499104e+07                 1764146         8.497618
# 41         42        8.945768e+06                  802646        11.145347
# 42         43        1.639169e+07                 2182356         7.511007
# 43         44        6.208755e+07                 7273093         8.536609
# 44         45        5.449801e+07                 6201115         8.788421
# 45         46        4.189606e+07                 5990113         6.994202
# 46         47        5.094831e+07                 6535810         7.795256
# 47         48        3.593313e+07                 5107785         7.034973
# 48         49        4.342010e+07                 4574103         9.492592
# 49         50        2.865302e+07                 4384444         6.535155
# 50         51        3.291149e+07                 2873614        11.452996
# 51         52        2.696170e+06                  275393         9.790262
# 52         53        1.121617e+07                 1180082         9.504566
# 53         54        1.105748e+07                 1451290         7.619072
#
#     Dias com dados  Media do faturamento por dia  Media de vendas por dia  \
# 0             1694                   8350.066629              1507.652302
# 1             1694                  12725.731195              1900.768005
# 2             1695                  29782.837867              3165.988201
# 3             1695                  11156.165416              1486.139823
# 4             1695                   9199.058745              1385.178171
# 5             1695                  14857.628317              1808.788201
# 6             1695                  15900.914208              1767.547493
# 7             1695                  17990.729751              2736.266077
# 8             1695                  15580.791189              2074.431858
# 9             1695                   5671.920788               974.922124
# 10            1695                  16711.243942              2343.650737
# 11            1635                   6519.399362              1198.074618
# 12            1695                   6208.286618               927.730973
# 13            1657                   6872.612401              1380.718165
# 14            1695                   6755.911518              1303.774631
# 15            1695                   6481.659324               864.010619
# 16            1693                  10650.306704              1355.868281
# 17            1585                   8365.536713              1306.800000
# 18            1695                   7698.825862              1243.356342
# 19             927                  13938.462344              1534.562028
# 20             766                  12082.905888              1100.379896
# 21             689                   5936.432135               731.721335
# 22            1695                   6873.970900              1054.968142
# 23            1594                  14910.748244              2238.523212
# 24            1634                   6989.594781               930.454100
# 25            1695                   4575.293152               628.353392
# 26            1695                  11320.366597              1466.482006
# 27            1695                  10845.519076              1154.922714
# 28             892                  10902.643157              1100.278027
# 29            1672                   4415.115828               700.436603
# 30            1695                  10470.131387              1360.497935
# 31            1695                   3511.384069               628.451917
# 32            1695                   8364.897518              1028.320354
# 33            1695                  10083.029002              2279.656637
# 34            1695                   4529.014408               663.061357
# 35            1569                   9765.730463              1107.794136
# 36            1694                  11789.041095              1465.005313
# 37            1695                  11126.843222              1691.476106
# 38            1695                  11948.196185              1409.723894
# 39            1695                  10852.954222              1286.840708
# 40            1695                   8844.270878              1040.794100
# 41             738                  12121.636701              1087.596206
# 42            1691                   9693.490368              1290.571260
# 43            1695                  36629.824926              4290.910324
# 44            1695                  32152.218535              3658.474926
# 45            1695                  24717.440780              3533.989971
# 46            1695                  30058.000036              3855.935103
# 47            1695                  21199.486887              3013.442478
# 48            1695                  25616.575684              2698.585841
# 49            1695                  16904.436947              2586.692625
# 50            1695                  19416.807987              1695.347493
# 51             134                  20120.669651              2055.171642
# 52            1185                   9465.120070               995.849789
# 53            1695                   6523.588860               856.218289
#
#     cluster
# 0         2
# 1         0
# 2         1
# 3         2
# 4         2
# 5         0
# 6         0
# 7         0
# 8         0
# 9         2
# 10        0
# 11        2
# 12        2
# 13        2
# 14        2
# 15        2
# 16        2
# 17        2
# 18        2
# 19        0
# 20        2
# 21        2
# 22        2
# 23        0
# 24        2
# 25        2
# 26        2
# 27        2
# 28        2
# 29        2
# 30        2
# 31        2
# 32        2
# 33        0
# 34        2
# 35        2
# 36        2
# 37        0
# 38        2
# 39        2
# 40        2
# 41        2
# 42        2
# 43        1
# 44        1
# 45        1
# 46        1
# 47        1
# 48        1
# 49        0
# 50        0
# 51        0
# 52        2
# 53        2

# %%
# Merge dos DataFrames utilizando a coluna 'store_nbr' como chave de junção
transactions = pd.merge(transactions, df_clusterizado[['store_nbr', 'cluster']], on='store_nbr', how='left')
transactions.head()
# Out:
#          date  store_nbr  transactions  cluster
# 0  2013-01-01         25           770        2
# 1  2013-01-02          1          2111        2
# 2  2013-01-02          2          2358        0
# 3  2013-01-02          3          3487        1
# 4  2013-01-02          4          1922        2

# %%
transactions.isnull().any()
# Out:
# date            False
# store_nbr       False
# transactions    False
# cluster         False
# dtype: bool

# %%
transactions.isnull().values.any()
# Out:
# False

# %%
transactions.isnull().sum()  # Conta a quantidade de valores nulos (incluindo `nan`) em cada coluna
# Out:
# date            0
# store_nbr       0
# transactions    0
# cluster         0
# dtype: int64

# %%
# Criando um dicionário e agrupando os dataframes por cluster
transactions_clusters = {}
grouped = transactions.groupby('cluster')
for cluster, group in grouped:
    transactions_clusters[cluster] = group

df_pqn = transactions_clusters[2]# DF Pequeno Porte
df_gnd = transactions_clusters[1]# DF Grande Porte
df_med = transactions_clusters[0]# DF Médio Porte

# %% [markdown]
# # Modelo Prophet

# %% [markdown]
# ## Loja de Grande Porte

# %%
df_gnd
# Out:
#              date  store_nbr  transactions  cluster
# 3      2013-01-02          3          3487        1
# 38     2013-01-02         44          4821        1
# 39     2013-01-02         45          4208        1
# 40     2013-01-02         46          4886        1
# 41     2013-01-02         47          4161        1
# ...           ...        ...           ...      ...
# 83478  2017-08-15         45          3685        1
# 83479  2017-08-15         46          3197        1
# 83480  2017-08-15         47          3581        1
# 83481  2017-08-15         48          2722        1
# 83482  2017-08-15         49          2814        1
#
# [11738 rows x 4 columns]

# %%
df_gnd['date'] = pd.to_datetime(df_gnd['date'])

# %%
# Criar um novo DataFrame filtrando os valores da coluna "store_nbr"
df_gnd = df_gnd[df_gnd['store_nbr'] == 44]

# %%
# Renomeie as colunas para o formato esperado pelo Prophet
df_gnd = df_gnd.rename(columns={'date': 'ds', 'transactions': 'y'})
df_gnd = df_gnd.drop(['store_nbr','cluster'], axis =1)

# %%
df_gnd.head()
# Out:
#             ds     y
# 38  2013-01-02  4821
# 84  2013-01-03  3618
# 130 2013-01-04  4169
# 176 2013-01-05  4921
# 222 2013-01-06  4925

# %%
# Divisão para treino e teste
proporcao_treino = 0.8  # 80% de dados para treino
tamanho_treino = int(len(df_gnd) * proporcao_treino)

# Separação dos dados para treino e teste
df_train = df_gnd.iloc[:tamanho_treino]  # Dados de treino
df_test = df_gnd.iloc[tamanho_treino:]   # Dados de teste

# Ajustes do modelo Prophet
model = Prophet(daily_seasonality=False, weekly_seasonality=True, yearly_seasonality=True)
model.add_country_holidays(country_name='EC')
model.fit(df_train)

# Dataframe com as datas futuras (180 dias)
future = model.make_future_dataframe(periods=180)

# Previsão
forecast = model.predict(future)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpks403h08/hhj3359_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpks403h08/5oyc8e_m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43363', 'data', 'file=/tmp/tmpks403h08/hhj3359_.json', 'init=/tmp/tmpks403h08/5oyc8e_m.json', 'output', 'file=/tmp/tmpks403h08/prophet_modellxa1etbh/prophet_model-20240429001254.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 00:12:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:12:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Visualizar as previsões
fig = model.plot(forecast)
plt.title('Previsão de uma loja de grande porte')
plt.xlabel('Data')
plt.ylabel('Valor de Abertura')
plt.show()

# %%
import matplotlib.pyplot as plt

# Visualizar as previsões
fig = model.plot(forecast)
plt.title('Previsão de vendas de uma loja de grande porte')
plt.xlabel('Data')
plt.ylabel('Quantidade de vendas')
plt.gcf().set_size_inches(8, 6)
plt.savefig('previsao_vendasD2_GP.png', dpi=300)
plt.show()

# %%
model.plot_components(forecast);

# %% [markdown]
# ### Validação do Modelo

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import numpy as np

# %%
# Avaliando as previsões e comparando com os dados de teste
test_results = forecast[['ds', 'yhat']].iloc[-len(df_test):]
comparison_df = df_test.set_index('ds').join(test_results.set_index('ds'))
# Verificando se há valores ausentes
print(comparison_df.isna().sum())
comparison_df = comparison_df.dropna()
# Out:
# y         0
# yhat    158
# dtype: int64

# %%
# Calculo do RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(comparison_df['y'], comparison_df['yhat']))
print(f'RMSE: {rmse}')

# Calculo do MAE (Mean Absolute Error)
mae = mean_absolute_error(comparison_df['y'], comparison_df['yhat'])
print(f'MAE: {mae}')

# Filtro de valores zero em y e as correspondentes previsões yhat
valid_indices = comparison_df['y'] != 0
y_filtered = comparison_df['y'][valid_indices]
yhat_filtered = comparison_df['yhat'][valid_indices]

# Calculo do MAPE filtrado
mape = mean_absolute_percentage_error(y_filtered, yhat_filtered) * 100

print(f'MAPE: {mape}%')
#Acurácia Baseada no MAPE
accuracy = 100 - mape
print(f'Acurácia do modelo: {accuracy:.2f}%')
# Out:
# RMSE: 505.30280354416027
# MAE: 367.09340055279654
# MAPE: 7.5464921567456695%
# Acurácia do modelo: 92.45%

# %% [markdown]
# ## Loja de Pequeno Porte

# %%
df_pqn.head()
# Out:
#           date  store_nbr  transactions  cluster
# 0   2013-01-01         25           770        2
# 1   2013-01-02          1          2111        2
# 4   2013-01-02          4          1922        2
# 5   2013-01-02          5          1903        2
# 10  2013-01-02         10          1293        2

# %%
df_pqn.isnull().sum()
# Out:
# date            0
# store_nbr       0
# transactions    0
# cluster         0
# dtype: int64

# %%
df_pqn['date'] = pd.to_datetime(df_pqn['date'])

# %%
# Dataframe com a Loja de pequeno Porte escolhida
df_pqn = df_pqn[df_pqn['store_nbr'] == 31]

# %%
# Renomeando as colunas para o formato esperado pelo Prophet
df_pqn = df_pqn.rename(columns={'date': 'ds', 'transactions': 'y'})
df_pqn = df_pqn.drop(['store_nbr','cluster'], axis =1)

# %%
df_pqn.head()
# Out:
#             ds     y
# 27  2013-01-02  1401
# 73  2013-01-03  1126
# 119 2013-01-04  1246
# 165 2013-01-05  1317
# 211 2013-01-06  1468

# %%
# Divisão para treino e teste
proporcao_treino = 0.8  # 80% de dados para treino
tamanho_treino = int(len(df_pqn) * proporcao_treino)

# Separando os dados de treino e teste
df_train = df_pqn.iloc[:tamanho_treino]  # Dados de treino
df_test = df_pqn.iloc[tamanho_treino:]   # Dados de teste

# Criando e ajustando o modelo Prophet
model = Prophet(daily_seasonality=False, weekly_seasonality=True, yearly_seasonality=True)
model.add_country_holidays(country_name='EC')
model.fit(df_train)

# Previsão
future = model.make_future_dataframe(periods=180)
forecast = model.predict(future)

# Visualizar as previsões
fig = model.plot(forecast)
plt.title('Previsão de uma loja de pequeno porte')
plt.xlabel('Data')
plt.ylabel('Valor de Abertura')
plt.show()
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpks403h08/6ix7n4hb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpks403h08/a2pw0x3k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40842', 'data', 'file=/tmp/tmpks403h08/6ix7n4hb.json', 'init=/tmp/tmpks403h08/a2pw0x3k.json', 'output', 'file=/tmp/tmpks403h08/prophet_modeltqavponk/prophet_model-20240429001312.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 00:13:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:13:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
import matplotlib.pyplot as plt

# Visualizar as previsões
fig = model.plot(forecast)
plt.title('Previsão de vendas de uma loja de pequeno porte')
plt.xlabel('Data')
plt.ylabel('Quantidade de vendas')
plt.gcf().set_size_inches(8, 6)
plt.savefig('previsao_vendasd2_PP.png', dpi=300)
plt.show()

# %%
model.plot_components(forecast);

# %% [markdown]
# ### Validação do Modelo

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import numpy as np

# %%
# Avaliando as previsões e comparando com os dados de teste
test_results = forecast[['ds', 'yhat']].iloc[-len(df_test):]
comparison_df = df_test.set_index('ds').join(test_results.set_index('ds'))

# Verificando se há valores ausentes
print(comparison_df.isna().sum())
comparison_df = comparison_df.dropna()
# Out:
# y         0
# yhat    158
# dtype: int64

# %%
# Calculo do RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(comparison_df['y'], comparison_df['yhat']))
print(f'RMSE: {rmse}')

# Calculo do MAE (Mean Absolute Error)
mae = mean_absolute_error(comparison_df['y'], comparison_df['yhat'])
print(f'MAE: {mae}')

# Filtrar valores zero em y e as correspondentes previsões yhat
valid_indices = comparison_df['y'] != 0
y_filtered = comparison_df['y'][valid_indices]
yhat_filtered = comparison_df['yhat'][valid_indices]

# Calculo do MAPE filtrado
mape = mean_absolute_percentage_error(y_filtered, yhat_filtered) * 100

print(f'MAPE: {mape}%')

# Calcule a acurácia como 100% menos o MAPE
accuracy = 100 - mape
print(f'Acurácia do modelo: {accuracy:.2f}%')
# Out:
# RMSE: 225.2136554382997
# MAE: 140.22894260561011
# MAPE: 8.98346403772882%
# Acurácia do modelo: 91.02%
